# %%
#Importing the required packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from fbprophet import Prophet

# %%
#Importing the dataset from drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Loading the dataset as dataframe
#df_1 = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Project_ChicagoCrimeRate/Chicago_Crimes_2001_to_2004.csv",error_bad_lines=False)
df_1 = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Project_ChicagoCrimeRate/Chicago_Crimes_2005_to_2007.csv",error_bad_lines=False)
df_2 = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Project_ChicagoCrimeRate/Chicago_Crimes_2008_to_2011.csv",error_bad_lines=False)
df_3 = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Project_ChicagoCrimeRate/Chicago_Crimes_2012_to_2017.csv")
# Out:
# b'Skipping line 533719: expected 23 fields, saw 24\n'
# b'Skipping line 1149094: expected 23 fields, saw 41\n'

# %%
#Concataniting the three dataframes
df_chicago = pd.concat([df_1,df_2,df_3])

# %%
#Listing first 10 data entries
df_chicago.head(10)
# Out:
#    Unnamed: 0       ID  ...  Longitude                       Location
# 0           0  4673626  ... -87.771996  (41.981912692, -87.771996382)
# 1           1  4673627  ... -87.611920  (41.775732538, -87.611919814)
# 2           2  4673628  ... -87.593671  (41.769897392, -87.593670899)
# 3           4  4673629  ... -87.780057  (41.942984005, -87.780056951)
# 4           5  4673630  ... -87.716745   (41.784210853, -87.71674491)
# 5           6  4673631  ... -87.660982  (41.760401372, -87.660982392)
# 6           7  4673632  ... -87.757670   (41.972220564, -87.75766982)
# 7           8  4673633  ... -87.688304  (41.770925978, -87.688304107)
# 8           9  4673634  ... -87.676334  (41.895922672, -87.676333733)
# 9          10  4673635  ... -87.613191   (41.77945628, -87.613190628)
#
# [10 rows x 23 columns]

# %%
plt.figure(figsize = (10,10))
sns.heatmap(df_chicago.isnull(), cbar = False, cmap = 'YlGnBu')
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 4 threads.

# %%
df_chicago.drop(['Unnamed: 0', 'Case Number', 'ID', 'IUCR', 'X Coordinate', 'Y Coordinate', 'Updated On', 'Year', 'FBI Code', 'Ward', 'Community Area', 'Location', 'District', 'Latitude', 'Longitude', 'Beat'],  axis =1)
# Out:
#                            Date                 Block  ... Arrest Domestic
# 0        04/02/2006 01:00:00 PM     055XX N MANGO AVE  ...  False    False
# 1        02/26/2006 01:40:48 PM    065XX S RHODES AVE  ...   True    False
# 2        01/08/2006 11:16:00 PM       013XX E 69TH ST  ...  False    False
# 3        04/05/2006 06:45:00 PM   061XX W NEWPORT AVE  ...  False    False
# 4        02/17/2006 09:03:14 PM       037XX W 60TH ST  ...   True    False
# ...                         ...                   ...  ...    ...      ...
# 1456709  05/03/2016 11:33:00 PM       026XX W 23RD PL  ...   True     True
# 1456710  05/03/2016 11:30:00 PM   073XX S HARVARD AVE  ...   True     True
# 1456711  05/03/2016 12:15:00 AM       024XX W 63RD ST  ...  False    False
# 1456712  05/03/2016 09:07:00 PM  082XX S EXCHANGE AVE  ...  False     True
# 1456713  05/03/2016 11:38:00 PM       001XX E 75TH ST  ...   True    False
#
# [6017767 rows x 7 columns]

# %%
df_chicago.Date = pd.to_datetime(df_chicago.Date, format= '%m/%d/%Y %I:%M:%S %p')

# %%
df_chicago.index = pd.DatetimeIndex(df_chicago.Date)

# %%
df_chicago
# Out:
#                      Unnamed: 0  ...                       Location
# Date                             ...
# 2006-04-02 13:00:00           0  ...  (41.981912692, -87.771996382)
# 2006-02-26 13:40:48           1  ...  (41.775732538, -87.611919814)
# 2006-01-08 23:16:00           2  ...  (41.769897392, -87.593670899)
# 2006-04-05 18:45:00           4  ...  (41.942984005, -87.780056951)
# 2006-02-17 21:03:14           5  ...   (41.784210853, -87.71674491)
# ...                         ...  ...                            ...
# 2016-05-03 23:33:00     6250330  ...   (41.849222028, -87.69155551)
# 2016-05-03 23:30:00     6251089  ...   (41.760743949, -87.63333531)
# 2016-05-03 00:15:00     6251349  ...  (41.779234743, -87.685207125)
# 2016-05-03 21:07:00     6253257  ...  (41.745251975, -87.552773464)
# 2016-05-03 23:38:00     6253474  ...   (41.75830866, -87.620658418)
#
# [6017767 rows x 23 columns]

# %%
df_chicago['Primary Type'].value_counts().iloc[:15]
# Out:
# THEFT                         1245111
# BATTERY                       1079178
# CRIMINAL DAMAGE                702702
# NARCOTICS                      674831
# BURGLARY                       369056
# OTHER OFFENSE                  368169
# ASSAULT                        360244
# MOTOR VEHICLE THEFT            271624
# ROBBERY                        229467
# DECEPTIVE PRACTICE             225180
# CRIMINAL TRESPASS              171596
# PROSTITUTION                    60735
# WEAPONS VIOLATION               60335
# PUBLIC PEACE VIOLATION          48403
# OFFENSE INVOLVING CHILDREN      40260
# Name: Primary Type, dtype: int64

# %%
list = df_chicago['Primary Type'].value_counts().iloc[:15].index

# %%
plt.figure(figsize= (15, 10))
sns.countplot(y= 'Primary Type', data = df_chicago, order = list)

# %%
plt.figure(figsize= (15, 10))
sns.countplot(y = 'Location Description',data= df_chicago, order = df_chicago['Location Description'].value_counts().iloc[:15].index)

# %%
df_chicago.resample('Y').size()
# Out:
# Date
# 2005-12-31    455811
# 2006-12-31    794684
# 2007-12-31    621848
# 2008-12-31    852053
# 2009-12-31    783900
# 2010-12-31    700691
# 2011-12-31    352066
# 2012-12-31    335670
# 2013-12-31    306703
# 2014-12-31    274527
# 2015-12-31    262995
# 2016-12-31    265462
# 2017-12-31     11357
# Freq: A-DEC, dtype: int64

# %%
plt.plot(df_chicago.resample('Y').size())

# %%
prophet_chic = df_chicago.resample('M').size().reset_index()

# %%
prophet_chic.columns = ['Date', 'Crime Count']

# %%
prophet_chic_final = prophet_chic.rename(columns= {'Date': 'ds', 'Crime Count': 'y'})

# %%
model = Prophet()
model.fit(prophet_chic_final)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = model.make_future_dataframe(periods = 720)
forecast = model.predict(future)

# %%
figure = model.plot(forecast, xlabel = 'Date', ylabel = 'Crime Rate')

# %%
figure = model.plot_components(forecast)
